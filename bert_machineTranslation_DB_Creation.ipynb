# %%
from sqlalchemy import create_engine
import os
import pandas as pd

DB_SERVER = "(LocalDb)\\MSSQLLocalDB"
DB_NAME = 'Bank'

# Local Execution with Local Client
p = {
    'Server': DB_SERVER,
    'Database': DB_NAME
}

# Windows OS Driver selection for Local "VSCode/Shell" usage
if os.name == 'nt':
    driver = 'SQL Server Native Client 11.0'

# Linux OS Driver selection for Local "Analyticlab/AILab" usage
else:
    driver = 'ODBC Driver 17 for SQL Server'
 
# Local Engine Creation (User Name & Password are not required)
engine = create_engine(
    'mssql://' + p['Server'] + '/' + p['Database'] +'?driver=' + driver,
    echo=False,        
    fast_executemany=True)
print (engine)
# Out:
# Engine(mssql://(LocalDb)\MSSQLLocalDB/Bank_deneme?driver=SQL+Server+Native+Client+11.0)

# %%
df1 = pd.read_excel('DB_TurkToSQL_[Cheque].xlsx', sheet_name='Sheet1')

display(df1)
# Out:
#        ChequeNo  persontype ChequeClearanceStatusCode  ChequeAmount  \
# 0       4718549           1                       TAH       65000.0
# 1       6500127           1                       TAH       12335.6
# 2       2726489           1                       TAH        7752.0
# 3       8033271           1                       TAH       25000.0
# 4       9102528           1                       TAH       15000.0
# ...         ...         ...                       ...           ...
# 19995    999692           0                        KR       15000.0
# 19996    261737           0                       TAH       10000.0
# 19997     10075           0                       TAH       30000.0
# 19998   8863385           0                       TAH       10000.0
# 19999    998476           0                       TAH        7000.0
#
#       ChequeMaturityDate
# 0             2021-04-26
# 1             2019-08-26
# 2             2018-02-12
# 3             2021-06-02
# ...

# %%
# Export the DataFrame to SQLite
df1.to_sql('Cheque', engine, schema='CHQ', index=False, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File c:\Users\AKDEMNB\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\AKDEMNB\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py:3300, in Engine.raw_connection(self)
#    3279 """Return a "raw" DBAPI connection from the connection pool.
#    3280
#    3281 The returned object is a proxied version of the DBAPI
#    (...)
#    3298
#    3299 """
# -> 3300 return self.pool.connect()
#
# File c:\Users\AKDEMNB\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
# ...

# %%
# Verify the data is in the SQLite database
query = 'SELECT * FROM [Bank_deneme].[CHQ].[Cheque]'
result = pd.read_sql(query, engine)

# Print the result
print(result)
